# %% [markdown]
# # View Model
# Make data show in beauty
# * matplotlib
# * numpy
# * pandas

# %%
from IMP import NotebookLoader, NotebookFinder
import numpy as np
import pandas as pd

# %matplotlib inline
from pylab import plot

# %%
plot([np.sin(x) for x in np.arange(-3.14, 3.14, 1e-1)])

# %%
a = np.random.rand(5,6)

# %%
df = pd.DataFrame(a)

# %%
df[2] = df[2]*10
df.style.background_gradient()
# Out:
#         <style  type="text/css" >
#
#
#             #T_a1ed6fb0_191d_11e6_834b_0030677f6017row0_col0 {
#
#                 background-color:  #589ec8;
#
#             }
#
#             #T_a1ed6fb0_191d_11e6_834b_0030677f6017row0_col1 {
#
#                 background-color:  #4e9ac6;
#
#             }
#
#             #T_a1ed6fb0_191d_11e6_834b_0030677f6017row0_col2 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_a1ed6fb0_191d_11e6_834b_0030677f6017row0_col3 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_a1ed6fb0_191d_11e6_834b_0030677f6017row0_col4 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_a1ed6fb0_191d_11e6_834b_0030677f6017row0_col5 {
#
#                 background-color:  #023858;
#
#             }
#
#             #T_a1ed6fb0_191d_11e6_834b_0030677f6017row1_col0 {
#
#                 background-color:  #fff7fb;
#
#             }
#
# ...
